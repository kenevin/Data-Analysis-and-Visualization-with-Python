# %%
import matplotlib.pyplot as plt
print plt.__doc__
print dir(plt)
# %matplotlib inline
# Out:
# Provides a MATLAB-like plotting framework.
#
# :mod:`~matplotlib.pylab` combines pyplot with numpy into a single namespace.
# This is convenient for interactive work, but for programming it
# is recommended that the namespaces be kept separate, e.g.::
#
#     import numpy as np
#     import matplotlib.pyplot as plt
#
#     x = np.arange(0, 5, 0.1);
#     y = np.sin(x)
#     plt.plot(x, y)
#
#
# ...

# %%
import numpy as np

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
plt.plot(x, y, '.')

# %%
y2 = np.cos(x)
plt.plot(x, y, color = 'blue')
plt.plot(x, y2, color = 'red')
plt.legend(loc = 1)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
y2 = np.cos(x)
plt.plot(x, y, color = 'blue', label = 'sin(x)')
plt.plot(x, y2, color = 'red', label = 'cos(x)')
plt.legend(loc = 1) # Need to use label and color  to get the legend to work properly

# %%
y2 = np.cos(x)
plt.plot(x, y, color = 'blue', label = 'sin(x)')
plt.plot(x, y2, color = 'red', label = 'cos(x)')
plt.legend(loc = 3) # Need to use label and color  to get the legend to work properly

# %%
intersection = np.linspace(0.785, 3.92, 100)
plt.plot(x, y, color = 'blue', label = 'sin(x)')
plt.plot(x, y2, color = 'red', label = 'cos(x)')
plt.fill(intersection, np.sin(intersection), color = 'grey', alpha = 1)
plt.fill(intersection, np.cos(intersection), color = 'grey', alpha = 0.3) # Alpha sets the transparency
# plt.fill creates a straight line between the twop points specified and fills in the area.

# %%
y2 = np.cos(x)
plt.plot(x, y, color = 'blue', label = 'sin(x)')
plt.plot(x, y2, color = 'red', label = 'cos(x)')
#
plt.fill(np.concatenate([intersection, intersection[::-1]]), \
        np.concatenate([np.sin(intersection), np.cos(intersection[::-1])]),
        color = 'grey', alpha = 0.5)
#
plt.title('$sin(x)$ vs $cos(x)$')
plt.text(1.6, 0, '$sin(x) > cos(x)$', fontsize = 20)

# %%
y2 = np.cos(x)
plt.plot(x, y, color = 'blue', label = 'sin(x)')
plt.plot(x, y2, color = 'red', label = 'cos(x)')
#
plt.fill(np.concatenate([intersection, intersection[::-1]]), \
        np.concatenate([np.sin(intersection), np.cos(intersection[::-1])]))
#
plt.title('$sin(x)$ vs $cos(x)$')
plt.text(1.6, 0, '$sin(x) > cos(x)$', fontsize = 20)
#
plt.xlabel('x', fontsize = 15)
plt.ylabel('y', fontsize = 15)
plt.xticks(fontsize = 10, rotation = 45)
plt.yticks(fontsize = 10, rotation = 0)
plt.xlim(-0.5, 5.5)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
# Statistical plots
# scatter: correlation of two variables
# historgram: distribution of continuous variable
# barplot: show the difference between two factors
#

# %%
class Abalone(object):
    def __init__(self, sex, length, diameter, height, whole_weight, shucked_weight, viscera_weight, shell_weight, rings):
        self.sex = sex
        self.length = float(length)
        self.diameter = float(diameter)
        self.height = float(height)
        self.whole_weight = float(whole_weight)
        self.shucked_weight = float(shucked_weight)
        self.viscera_weight = float(viscera_weight)
        self.rings = int(rings)
    
    def data(self):
        return [self.sex, self.length, self.diameter, self.height, self.whole_weight, \
                self.shucked_weight, self.viscera_weight, self.rings]

with open('data/abalone.data') as f:
    abalone_file = f.readlines()
    abalones = [Abalone(*row.split(',')) for row in abalone_file]

# %%
def counter(raw_list):
    '''
    raw_slist: a list
    
    returns: a dict contains each word and it's corresponding frequency
    '''
    result = {}
    for word in raw_list:
        if word in result.keys():
            result[word] += 1
        else:
            result[word] = 1
    return result

# %%
rings = counter([i.rings for i in abalones])
rings
# Out:
# {1: 1,
#  2: 1,
#  3: 15,
#  4: 57,
#  5: 115,
#  6: 259,
#  7: 391,
#  8: 568,
#  9: 689,
#  10: 634,
#  11: 487,
#  12: 267,
#  13: 203,
#  14: 126,
#  15: 103,
#  16: 67,
#  17: 58,
#  18: 42,
#  19: 32,
#  20: 26,
#  21: 14,
#  22: 6,
#  23: 9,
#  24: 2,
#  25: 1,
#  26: 1,
#  27: 2,
#  29: 1}

# %%
# Scatter: use the command scatter
Height = [i.height for i in abalones]
Length = [i.length for i in abalones]

plt.scatter(Length, Height, alpha = 0.1)
#
plt.xlabel('Longest shell measurement')
plt.ylabel('With meat in shell')

# %%
import numpy as np
Ring = [i.rings for i in abalones]

# %%
plt.hist(Ring, alpha = 0.3)
# Out:
# (array([   17.,   431.,  1648.,  1388.,   329.,   228.,   100.,    29.,
#             4.,     3.]),
#  array([  1. ,   3.8,   6.6,   9.4,  12.2,  15. ,  17.8,  20.6,  23.4,
#          26.2,  29. ]),
#  <a list of 10 Patch objects>)

# %%
x = plt.hist(Ring, alpha = 0.3)
print x
# Out:
# (array([   17.,   431.,  1648.,  1388.,   329.,   228.,   100.,    29.,
#            4.,     3.]), array([  1. ,   3.8,   6.6,   9.4,  12.2,  15. ,  17.8,  20.6,  23.4,
#         26.2,  29. ]), <a list of 10 Patch objects>)

# %%
plt.hist(Ring, alpha = 0.3);

# %%
plt.hist(Ring, bins = 25, alpha = 0.3);

# %%
# BARPLOTS
sexCount = counter([i.sex for i in abalones])
sexCount = sorted(sexCount.items(), key = lambda x: x[1])
sexCount
# Out:
# [('F', 1307), ('I', 1342), ('M', 1528)]

# %%
keys = [i[0] for i in sexCount]
values = [i[1] for i in sexCount]

# %%
plt.bar(np.arange(len(keys)), values, width = 0.35, alpha = 0.3)
plt.xticks(np.arange(3) + 0.35/2, keys, fontsize = 15)
plt.xlabel('SEX')
plt.ylabel('Frequency')
for i in range(len(values)): # creating data labels
    plt.text(i + 0.1, values[i] + 10, values[i])

# %%
# BOXPLOTS

# %%
plt.rcParams['figure.figsize'] = 4, 6
plt.boxplot(Length)
plt.text(1.1, 0.2, '$Q_1 - 1.5(Q_3-Q_1)$')
plt.text(1.1, 0.53, '$Q_2$:50%')
plt.text(1.1, 0.60, '$Q_3$:75%')
plt.text(1.1, 0.80, '$Q_1 + 1.5(Q_3-Q_1)$')
plt.text(1.1, 0.1, '+: outliers', color = 'blue', fontsize = 15)
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %%
# SUBPLOTS

# %%
plt.rcParams['figure.figsize'] = 12, 6
# The first subplot
plt.subplot(131) # Grid with 1 row, 3 columns and right now we are only talking about the first plot
plt.boxplot(Length)
plt.xticks([])
plt.title('Boxplot of Length')

# The second subplot
plt.subplot(132) # Now let's refer to the second axis in this grid
plt.boxplot(Height)
plt.xticks([])
plt.title('Boxplot of Height')

# The third subplot
plt.subplot(133) # Now, let's refer to the third axis
plt.boxplot(Ring)
plt.xticks([])
plt.title('Boxplot of Ring')

# %%
plt.rcParams['figure.figsize'] = 12, 6
#
plt.subplot(221)
plt.scatter(Length, Height, alpha = 0.3)
# the second subplot
plt.subplot(222)
plt.scatter(Height, Ring, alpha = 0.3)
# the third subplot
plt.subplot(223)
plt.scatter(Length, Ring, alpha = 0.3)

# %%
# Saving figures
plt.rcParams['figure.figsize'] = 12, 6
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.savefig('pic/matplotlib_example.jpg')

# %%
import os #explore this library

# %%
from IPython.display import Image
Image('pic/matplotlib_example.jpg')

# %%
#PANDAS
# Main data analysis library
# Gives us two primary objects of interest: data frame and series

# Series: 1D labeled homogeneously-typed array
# TimeSeries: Series with index containing datetimes
# DataFrame: General 2D labeled, size mutable tabular structure with potentially heterogeneously-typed columns
# PAnel: General 3D labeled, also size-mutable array

# %%
import pandas as pd
obj = pd.Series(['a', 'b', 'c', 'd'])
obj
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
obj.index = ['A', 'B', 'C', 'D']
obj
# Out:
# A    a
# B    b
# C    c
# D    d
# dtype: object

# %%
obj['A']
# Out:
# 'a'

# %%
obj[['A', 'B', 'C']]
# Out:
# A    a
# B    b
# C    c
# dtype: object

# %%
x = ['A', 'B', 'C']
obj[x]
# Out:
# A    a
# B    b
# C    c
# dtype: object

# %%
dict = {1: 'a', 2: 'b', 3: 'c', 4: 'd'}
obj3 = pd.Series(dict)
obj3
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
obj3.to_dict() # Convert a series back to a dictionary
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
# DataFrames
# Represents a tabular, spreadsheet like data structure containing an ordered collection of columns, each of which can be a different value typ (eg, int, float, string, boolean)

# %%
# Creat a dictionary
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}
# Convert to dataframe
df = pd.DataFrame(data)
df
# Out:
#    pop   state  year
# 0  1.5    Ohio  2000
# 1  1.7    Ohio  2001
# 2  3.6    Ohio  2002
# 3  2.4  Nevada  2001
# 4  2.9  Nevada  2002

# %%
df.index # row name, it's 0, 1, 2, 3.. in default
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.values # values: multi-dimension array
# Out:
# array([[1.5, 'Ohio', 2000],
#        [1.7, 'Ohio', 2001],
#        [3.6, 'Ohio', 2002],
#        [2.4, 'Nevada', 2001],
#        [2.9, 'Nevada', 2002]], dtype=object)

# %%
df.columns # column name
# here u'pop' means the string 'pop' is encoded by unicode
# Out:
# Index([u'pop', u'state', u'year'], dtype='object')

# %%
[x for x in df.columns if "e" in x]
# Out:
# ['state', 'year']

# %%
df.year # retrieve by attribute
# When you retrieve a single column you are turning the column into a series.
# This is like a class instance
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# Name: year, dtype: int64

# %%
df['year'] # retrieve by dictionary-like attribute
# This is better because you can pass the column name with special characters or white space.
# For example, if "year" were instead "year of the rat" then the attribute type retrieval isn't really possibly.
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# Name: year, dtype: int64

# %%
# Dictionary notation is also required if you want to retrieve multiple columns
df[['year', 'state']]
# This returns a data frame.
# Out:
#    year   state
# 0  2000    Ohio
# 1  2001    Ohio
# 2  2002    Ohio
# 3  2001  Nevada
# 4  2002  Nevada

# %%
df[['year']]
# If you pass a string as part of series, it will return a data frame.
# Out:
#    year
# 0  2000
# 1  2001
# 2  2002
# 3  2001
# 4  2002

# %%
# Plotting functions in pandas

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(-5, 5, 300)
# create a series
s = pd.Series(np.sin(x), index =x)
s.plot()

# %%
s.plot(kind = 'hist', alpha = 0.3)

# %%
s.hist(bins = 50, alpha = 0.3)

# %%
s.plot(kind = 'bar', xticks = [], alpha = 0.3)

# %%
s.plot(kind = 'box')

# %%
df = pd.DataFrame({'sin(x)': np.sin(x), 'cos(x)' : np.cos(x)}, index = x)
df
# Out:
#              cos(x)    sin(x)
# -5.000000  0.283662  0.958924
# -4.966555  0.251438  0.967873
# -4.933110  0.218934  0.975740
# -4.899666  0.186184  0.982515
# -4.866221  0.153226  0.988191
# -4.832776  0.120096  0.992762
# -4.799331  0.086833  0.996223
# -4.765886  0.053472  0.998569
# -4.732441  0.020051  0.999799
# -4.698997 -0.013392  0.999910
# -4.665552 -0.046820  0.998903
# -4.632107 -0.080196  0.996779
# -4.598662 -0.113482  0.993540
# -4.565217 -0.146641  0.989190
# -4.531773 -0.179636  0.983733
# -4.498328 -0.212430  0.977176
# -4.464883 -0.244987  0.969526
# -4.431438 -0.277269  0.960792
# -4.397993 -0.309242  0.950983
# -4.364548 -0.340868  0.940111
# -4.331104 -0.372114  0.928187
# -4.297659 -0.402943  0.915225
# -4.264214 -0.433321  0.901239
# -4.230769 -0.463215  0.886246
# -4.197324 -0.492591  0.870261
# -4.163880 -0.521416  0.853303
# -4.130435 -0.549658  0.835390
# -4.096990 -0.577284  0.816543
# -4.063545 -0.604266  0.796783
# -4.030100 -0.630571  0.776132
# ...

# %%
df.plot(title = '$sin(x)$ VS. $cos(x)$')

# %%
import matplotlib.pyplot as plt
with plt.style.context("fivethirtyeight"):
    df.plot(title = '$sin(x)$ VS $cos(x)$')
    plt.legend(loc = 1)
# Steven Few Data Visualization

# %%
with plt.style.context("ggplot"):
    df.plot(title = '$sin(x)$ VS $cos(x)$')
    plt.legend(loc = 1)

# %%
df = pd.DataFrame(np.random.randn(6,4),
                 index = ['one', 'two', 'three', 'four', 'five', 'six'],
                 columns = pd.Index(['A', 'B', 'C', 'D'], name = 'Bar'))
print df
df.plot(kind = 'bar', alpha = 0.5, title = 'Bar Plot')
# Out:
# Bar           A         B         C         D
# one   -1.423615  0.730943 -1.332460 -0.724541
# two   -0.558126  0.419147  0.685227  1.371020
# three  0.768725 -0.653333  0.206238 -1.375662
# four  -1.558348  0.739752  0.036900  0.622291
# five   1.270232  1.686643  1.256870 -2.852858
# six   -0.581594 -0.195195  0.804833 -0.095031

# %%
df = pd.DataFrame(np.random.randn(6,4),
                 index = pd.Index(['one', 'two', 'three', 'four', 'five', 'six'], name = 'The Indices'),
                 columns = pd.Index(['A', 'B', 'C', 'D'], name = 'Bar'))
print df
df.plot(kind = 'bar', alpha = 0.5, title = 'Bar Plot')
# Out:
# Bar                 A         B         C         D
# The Indices
# one         -1.094689  1.583317  0.559059 -0.742458
# two          2.245214  0.738182  1.178790  1.116757
# three       -0.474923  1.030268  1.504148  0.858201
# four        -0.815116 -0.079013  0.475886  0.228602
# five        -0.783989  0.455417 -2.791799  0.091041
# six          0.868101  0.433741 -0.451594  0.985087

# %%
df.plot(kind = 'barh', stacked = True, alpha = 0.5, title = 'Stacked Bar Plot')

# %%
df["A"].plot(kind = 'barh', title = 'Bar A')

# %%
from scipy import stats

# %%
n = 1e3
df = pd.DataFrame({'norm': stats.norm.rvs(size = n),
                  'binomial': stats.binom.rvs(10, 0.5, size = n),
                  'poisson': stats.poisson.rvs(5, size = n),
                  't': stats.t.rvs(30, size = n)})
df.head(7)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:128: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return self._random_state.standard_normal(self._size)
# /Applications/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:225: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /Applications/anaconda/lib/python2.7/site-packages/scipy/stats/_discrete_distns.py:40: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return self._random_state.binomial(n, p, self._size)
# /Applications/anaconda/lib/python2.7/site-packages/scipy/stats/_discrete_distns.py:453: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ...

# %%
df.hist(alpha = 0.5);

# %%
df.hist(alpha = 0.5, sharex = True, sharey = True); # Force all plots to use the same scale.

# %%
df.hist(layout = (1, 4), alpha = 0.5, figsize = (16, 3), sharey = True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1210ec8d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12147c350>]], dtype=object)

# %%
df.plot(kind = 'box', figsize = (16, 4), subplots = True)
# Out:
# binomial       Axes(0.125,0.125;0.168478x0.775)
# norm        Axes(0.327174,0.125;0.168478x0.775)
# poisson     Axes(0.529348,0.125;0.168478x0.775)
# t           Axes(0.731522,0.125;0.168478x0.775)
# dtype: object

# %%
df.plot(kind = 'box', figsize = (16, 4))

# %%
pd.scatter_matrix(df, alpha = 0.8, figsize = (16,4));

# %%
#SEABORN

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %matplotlib inline

# %%
x = np.random.randn(1e3)
y = 2*x + np.random.randn(1e3)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   from ipykernel import kernelapp as app

# %%
sns.kdeplot(x, shade = True, label = 'Estimated PDF') # kde = kernel density estimate

seq = np.linspace(-5, 5, 100)
plt.plot(seq, stats.norm.pdf(seq), color = 'red', label = 'True PDF');
plt.legend(loc = 1);

# %%
sns.distplot(x);

# %%
import pandas as pd
n = 1e3
df = pd.DataFrame({'norm': stats.norm.rvs(size = n),
                  'binomial': stats.binom.rvs(10, 0.5, size = n),
                  'poisson': stats.poisson.rvs(5, size = n),
                  't': stats.t.rvs(30, size = n)})
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:128: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return self._random_state.standard_normal(self._size)
# /Applications/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:225: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /Applications/anaconda/lib/python2.7/site-packages/scipy/stats/_discrete_distns.py:40: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return self._random_state.binomial(n, p, self._size)
# /Applications/anaconda/lib/python2.7/site-packages/scipy/stats/_discrete_distns.py:453: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ...

# %%
sns.boxplot(df)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/seaborn/categorical.py:2171: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(df)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/seaborn/categorical.py:2342: UserWarning: The violinplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
df = pd.DataFrame(df, columns = ['t', 'norm', 'binomial', 'poisson'])
sns.violinplot(df)

# %%
df = pd.DataFrame(df, columns = ['t', 'norm', 'binomial', 'poisson'])
sns.violinplot(df, inner = "quartile")

# %%
sns.jointplot(df["norm"], df["t"])

# %%
sns.jointplot(x, y, kind = 'hex')

# %%
sns.jointplot(x, y, kind = 'reg')

# %%
# Correlation measures how cohesively two variables move with each other.
# p-value: the probability of finding a statistic as extreme or more extreme than the one we obtained if we assume the null hypothesis under the proposed model.
# we think of this as being greater than or less than a given number called alpha. If it's greater, it's significant. If it's less than, it is not significant.
# In practice we set the boundary at 0.05.
# Check out Kahn Academy for videos on Null hypothesis significant testing, p-value, z-test for proportions, t-tests anova, standard error, statistical power, etc.
# Udacity: A/B testing by Google
